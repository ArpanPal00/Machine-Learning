# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating DataFrame in Pandas

# %%
forestArea = {
    'Assam':pd.Series([78438,2797,10192,15116],index=['GeoArea', 'VeryDense','ModeratelyDense','OpenForest']),'Kerela':pd.Series([38852,1663,9407,9251],index=['GeoArea','VeryDense','ModeratelyDense','OpenForest']),'Delhi':pd.Series([1483,6.72,56.34,129.45],index=['GeoArea','VeryDense','ModeratelyDense','OpenForest'])
    }
df = pd.DataFrame(forestArea)
df
# Out:
#                  Assam  Kerela    Delhi
# GeoArea          78438   38852  1483.00
# VeryDense         2797    1663     6.72
# ModeratelyDense  10192    9407    56.34
# OpenForest       15116    9251   129.45

# %% [markdown]
# # Accesssing CSV Files using Pandas

# %%
marks = pd.read_csv('studentdata.csv',sep=',',header=1) #header=1 means the first row is the header row
marks = pd.read_csv('studentdata.csv')
marks
# Out:
#    1001       John       Doe  20   A         john.doe@example.com
# 0  1002       Jane     Smith  22   B       jane.smith@example.com
# 1  1003      Emily     Jones  21   C      emily.jones@example.com
# 2  1004    Michael     Brown  23  B+    michael.brown@example.com
# 3  1005       Liam   Johnson  20  A-     liam.johnson@example.com
# 4  1006        Ava  Martinez  22   B    jane.martinez@example.com
# 5  1007       Noah    Garcia  21   A      noah.garcia@example.com
# 6  1008   Isabella    Wilson  20  C+  isabella.wilson@example.com
# 7  1009     Oliver       Lee  23   B       oliver.lee@example.com
# 8  1010  Charlotte       Kim  21  A+    charlotte.kim@example.com

# %% [markdown]
# # Accessing Excel Files

# %%
excelFile = pd.read_excel('./students_data.xlsx')
print(excelFile.to_csv)
# Out:
# <bound method NDFrame.to_csv of     Student ID                   Name  Age Grade  \
# 0         4178            Lisa Montes   17     B
# 1         2882            Austin Diaz   14     A
# 2         3319         Travis Coleman   16     D
# 3         5231           Tonya Stokes   11     D
# 4         7251         Patrick Burton   14     C
# 5         2194          Richard Evans   15     E
# 6         3592            Laura Lopez   11     D
# 7         4106           Mary Collins   10     D
# 8         1901           Sabrina Beck   13     D
# 9         7331         Brooke Farrell   13     D
# 10        7819         Michael Norris   12     C
# 11        1633        Danny Rodriguez   14     B
# 12        1191             Erica Rice   11     D
# 13        9264           Tina Johnson   16     A
# 14        5552       Michael Williams   10     E
# 15        3153  Dr. Kimberly Perry MD   15     D
# 16        6311           Lauren Young   12     B
# ...

# %%
marks1 = pd.read_csv('studentdata.csv',header=0,names=['RollNo','Maths','English','Fourth','Fifth','Sixth'])
#marks1.to_csv('bundy.csv') #to save the file
#marks1.to_csv('bundy.csv',sep='|') #to change the separator
df =pd.DataFrame(marks1)
print(df)
print()
print(df.max(numeric_only=True)) #to get the max numeric value of the columns others are ignored

#dfUT2 = df[df.UT == 2] #to get the rows where UT is 2 #dfUT2.max() #to get the max value of the rows where UT is 2
#dfUT2_col_remove = dfUT2.drop('Name',axis=1) #to remove the Name column
#dfUT2.max(axis=1) #df.min(axis=0) #df.min(axis=1) #df+misti1 = df.loc[df.Name == 'Bundy'] #to get the rows where Name is Bundy
#df_misti.min() #df_misti[['maths'.......]].min()
#df_misti[['Maths','Sicence']].count(axis=1)
# Out:
#    RollNo      Maths   English  Fourth Fifth                        Sixth
# 0    1001       John       Doe      20     A         john.doe@example.com
# 1    1002       Jane     Smith      22     B       jane.smith@example.com
# 2    1003      Emily     Jones      21     C      emily.jones@example.com
# 3    1004    Michael     Brown      23    B+    michael.brown@example.com
# 4    1005       Liam   Johnson      20    A-     liam.johnson@example.com
# 5    1006        Ava  Martinez      22     B    jane.martinez@example.com
# 6    1007       Noah    Garcia      21     A      noah.garcia@example.com
# 7    1008   Isabella    Wilson      20    C+  isabella.wilson@example.com
# 8    1009     Oliver       Lee      23     B       oliver.lee@example.com
# 9    1010  Charlotte       Kim      21    A+    charlotte.kim@example.com
#
# RollNo    1010
# Fourth      23
# dtype: int64
